# %%
def print_board(board):
    print("\n")
    for row in board:
        print(" | ".join(row))
        print("-" * 5)
    print("\n")
def check_winner(board, player):
    for row in board:
        if all([cell == player for cell in row]):
            return True
    for col in range(3):
        if all([board[row][col] == player for row in range(3)]):
            return True
    if all([board[i][i] == player for i in range(3)]) or \
       all([board[i][2 - i] == player for i in range(3)]):
        return True
    return False
def is_full(board):
    return all(cell != " " for row in board for cell in row)
def tic_tac_toe():
    board = [[" "]*3 for _ in range(3)]
    current_player = "X"
    print("Welcome to Tic Tac Toe!\n")
    print("Player 1 = X, Player 2 = O")
    print_board(board)
    while True:
        try:
            move = input(f"Player {current_player}, enter row and column (1-3) separated by space: ")
            row, col = map(int, move.strip().split())
            row -= 1
            col -= 1

            if board[row][col] != " ":
                print("Cell already taken. Try again.")
                continue

            board[row][col] = current_player
            print_board(board)

            if check_winner(board, current_player):
                print(f"🎉 Player {current_player} wins! 🎉")
                break

            if is_full(board):
                print("It's a draw!")
                break

            current_player = "O" if current_player == "X" else "X"

        except (ValueError, IndexError):
            print("Invalid input. Please enter row and column like: 1 3")
            
tic_tac_toe()
# Out:
# Welcome to Tic Tac Toe!
#
# Player 1 = X, Player 2 = O
#
#
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
#
#
# Invalid input. Please enter row and column like: 1 3
#
#
#   | X |
# -----
#   |   |
# -----
#   |   |
# -----
#
#
#
#
#   | X |
# -----
# O |   |
# -----
#   |   |
# -----
#
#
# Cell already taken. Try again.
#
#
#   | X |
# -----
# O | X |
# -----
#   |   |
# -----
#
#
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# Invalid input. Please enter row and column like: 1 3
# ...

# %%
import random

def number_guess():
    num = random.randint(1, 100)
    attempts = 0
    print("Welcome to the Number Guessing Game!")
    
    while True:
        user_input = input("Guess a number between 1 and 100: ")
        
        if not user_input.isdigit():
            print("Please enter a valid number.")
            continue

        guess = int(user_input)
        attempts += 1

        if guess < num:
            print("Too low!")
        elif guess > num:
            print("Too high!")
        else:
            print(f"Correct! You guessed it in {attempts} attempts.")
            break

number_guess()
# Out:
# Welcome to the Number Guessing Game!
# Too low!
# Too high!
# Too high!
# Too high!
# Too high!
# Too high!
# Too low!
# Too high!
# Correct! You guessed it in 9 attempts.

# %%
import random

def word_scramble():
    words = ['python', 'jumble', 'programming', 'science', 'elephant', 'notebook', 'keyboard']
    word = random.choice(words)
    scrambled = ''.join(random.sample(word, len(word)))
    
    print("Welcome to the Word Scramble Game!")
    print("Unscramble the letters to make a valid word.")
    print(f"Scrambled word: {scrambled}")
    
    guess = input("Your guess: ").lower()
    
    if guess == word:
        print(" Correct! You guessed the word.")
    else:
        print(f" Wrong! The correct word was: {word}")

word_scramble()
# Out:
# Welcome to the Word Scramble Game!
# Unscramble the letters to make a valid word.
# Scrambled word: tnoeobko
#  Wrong! The correct word was: notebook
